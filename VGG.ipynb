# %%
from keras.layers import Flatten, Conv2D, MaxPooling2D, Dense, Dropout, Input, Activation
from keras.models import Model

# %%
# VGG-A
def vgg_a(x):
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(10)(x1)
    output = Activation('softmax')(x1)
    return output

input_img = Input(shape = (224,224,1))
VGG_A = Model(input_img,vgg_a(input_img))
VGG_A.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 224, 224, 64)      640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7, 7, 4096)        2101248
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7, 7, 4096)        16781312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7, 7, 10)          40970
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 7, 10)          0
# =================================================================
# Total params: 28,142,858
# Trainable params: 28,142,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG-B
def vgg_b(x):
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(10)(x1)
    output = Activation('softmax')(x1)
    return output

VGG_B = Model(input_img,vgg_b(input_img))
VGG_B.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 224, 224, 64)      640
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7, 7, 4096)        2101248
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_8 (Dense)              (None, 7, 7, 4096)        16781312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_9 (Dense)              (None, 7, 7, 10)          40970
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 10)          0
# =================================================================
# Total params: 28,327,370
# Trainable params: 28,327,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG-C
def vgg_c(x):
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (1,1), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (1,1), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (1,1), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling2D(pool_size=(2,2), strides=2)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(10)(x1)
    output = Activation('softmax')(x1)
    return output

VGG_C = Model(input_img,vgg_c(input_img))
VGG_C.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 224, 224, 64)      640
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 56, 56, 256)       65792
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 28, 28, 512)       262656
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 14, 14, 512)       262656
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# dense_10 (Dense)             (None, 7, 7, 4096)        2101248
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_11 (Dense)             (None, 7, 7, 4096)        16781312
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 7, 4096)        0
# _________________________________________________________________
# dense_12 (Dense)             (None, 7, 7, 10)          40970
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 10)          0
# =================================================================
# Total params: 28,918,474
# Trainable params: 28,918,474
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG-D
def vgg_d(x):
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(1)
    x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(10)(x1)
    output = Activation('softmax')(x1)
    return output

VGG_D = Model(input_img,vgg_d(input_img))
VGG_D.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py in assert_input_compatibility(self, inputs)
#     441             try:
# --> 442                 K.is_keras_tensor(x)
#     443             except ValueError:
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in is_keras_tensor(x)
#     468                           tf.SparseTensor)):
# --> 469         raise ValueError('Unexpectedly found an instance of type `' + str(type(x)) + '`. '
#     470                          'Expected a symbolic tensor instance.')
#
# ValueError: Unexpectedly found an instance of type `<class 'int'>`. Expected a symbolic tensor instance.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5ec50f5a4faf> in <module>()
#      27     return output
#      28
# ---> 29 VGG_D = Model(input_img,vgg_d(input_img))
#      30 VGG_D.summary()
#
# <ipython-input-23-5ec50f5a4faf> in vgg_d(x)
#       2 def vgg_d(x):
#       3     x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
# ----> 4     x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(1)
#       5     x1 = MaxPooling(pool_size=(2,2), strides=2)(x1)
#       6     x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     573                 # Raise exceptions in case the input is not compatible
#     574                 # with the input_spec specified in the layer constructor.
# --> 575                 self.assert_input_compatibility(inputs)
#     576
#     577                 # Collect input shapes to build layer.
#
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py in assert_input_compatibility(self, inputs)
#     446                                  'Received type: ' +
#     447                                  str(type(x)) + '. Full input: ' +
# --> 448                                  str(inputs) + '. All inputs to the layer '
#     449                                  'should be tensors.')
#     450
#
# ValueError: Layer conv2d_47 was called with an input that isn't a symbolic tensor. Received type: <class 'int'>. Full input: [1]. All inputs to the layer should be tensors.

# %%
# VGG-E
def vgg_e(x):
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(x)
    x1 = Conv2D(64, (3,3), padding = 'same', activation='relu')(1)
    x1 = MaxPool(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(128, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPool(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(256, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPool(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPool(pool_size=(2,2), strides=2)(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = Conv2D(512, (3,3), padding = 'same', activation='relu')(x1)
    x1 = MaxPool(pool_size=(2,2), strides=2)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(4096, activation='relu')(x1)
    x1 = Dropout(0.5)(x1)
    x1 = Dense(10)(x1)
    output = Activation('softmax')(x1)
    return output
